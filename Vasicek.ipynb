# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import pandas_datareader.data as web
from sklearn.linear_model import LinearRegression
from scipy.optimize import minimize

# %%
#Extracting 3 month interest rates of past 1 year
ir = web.DataReader('DGS3MO', 'fred', '2024-05-24', '2025-05-24')
ir['r(t) (*100%)']=ir['DGS3MO']/100     #Converting % to float
ir=ir.bfill()
del ir['DGS3MO']
ir['dr(t)']=ir['r(t) (*100%)']-ir['r(t) (*100%)'].shift(1)      #Change in interest rates
ir=ir[1:]
ir.head()
# Out:
#             r(t) (*100%)  dr(t)
# DATE
# 2024-05-27        0.0546    0.0
# 2024-05-28        0.0546    0.0
# 2024-05-29        0.0546    0.0
# 2024-05-30        0.0546    0.0
# 2024-05-31        0.0546    0.0

# %% [markdown]
# Vasicek Model: dr(t)=a(b-r(t))*dt + stdev(dW(t))

# %%
#Initial Estimation of Parameters
dt=1/252    #Daily Time Interval
r=np.array(ir['r(t) (*100%)'])
delta_r=np.array(ir['dr(t)'][1:])
r_lag = r[:-1]  

X = r_lag.reshape(-1, 1)
y = delta_r
reg = LinearRegression().fit(X, y)
alpha = reg.intercept_
beta = reg.coef_[0]

# Initial guesses
a_init = -beta / dt
b_init = alpha / (a_init * dt)
residuals = y - reg.predict(X)
sigma_init = np.std(residuals) / np.sqrt(dt)

# %%
ir['dr(t) (Model)']=a_init*(b_init-ir['r(t) (*100%)'])*dt
ir['Actual-Model']=ir['dr(t)']-ir['dr(t) (Model)']      #Actual-Model values
ir['PDF (Actual-Model)']=norm.pdf(ir['Actual-Model'], loc=0, scale=sigma_init)   #PDF of Actual-Model values
ir['ln(PDF)']=np.log(ir['PDF (Actual-Model)'])
sum_=ir['ln(PDF)'].sum()
ir.head()
# Out:
#             r(t) (*100%)  dr(t)  dr(t) (Model)  Actual-Model  \
# DATE
# 2024-05-27        0.0546    0.0      -0.000076      0.000076
# 2024-05-28        0.0546    0.0      -0.000076      0.000076
# 2024-05-29        0.0546    0.0      -0.000076      0.000076
# 2024-05-30        0.0546    0.0      -0.000076      0.000076
# 2024-05-31        0.0546    0.0      -0.000076      0.000076
#
#             PDF (Actual-Model)   ln(PDF)
# DATE
# 2024-05-27          120.844374  4.794504
# 2024-05-28          120.844374  4.794504
# 2024-05-29          120.844374  4.794504
# 2024-05-30          120.844374  4.794504
# 2024-05-31          120.844374  4.794504

# %%
#Optimization
initial_guess=[a_init,b_init,sigma_init]
neg_log_likelihood = lambda params: ( -np.sum(
        -0.5 * np.log(2 * np.pi * ((params[2]**2 / (2 * params[0])) * (1 - np.exp(-2 * params[0] * dt)))) 
        - ((r[1:] - (params[1] + (r_lag - params[1]) * np.exp(-params[0] * dt)))**2) / 
          (2 * ((params[2]**2 / (2 * params[0])) * (1 - np.exp(-2 * params[0] * dt))))
    )
    if params[0] > 0 and params[2] > 0 else np.inf) 
#Minimize Negative Log-Likelihood Function
result = minimize(
    neg_log_likelihood,
    x0=initial_guess,
    bounds=[(1e-5, None), (None, None), (1e-5, None)])
a_est, b_est, sigma_est = result.x

print(f"Estimated a = {a_est:.6f}")
print(f"Estimated b = {b_est:.6f}")
print(f"Estimated sigma = {sigma_est:.6f}")
# Out:
# Estimated a = 1.183260
# Estimated b = 0.038396
# Estimated sigma = 0.003308

# %%
#Modelling interest rates for 1 year ahead
current_rate=ir['r(t) (*100%)'].iloc[-1]
simulations=100
sim=[]
np.random.seed(0)
for i in range(simulations):
    sim.append([current_rate])
for i in range(simulations):
    for j in range(1,252):    #252 trading days in a year
        sim[i].append(((a_est/10)*(b_est-sim[i][j-1])*dt + sigma_est*(dt**0.5)*np.random.normal(loc=0,scale=1))+sim[i][j-1])
#Plotting the results
plt.figure(figsize=(20,4))
for path in sim:
    plt.plot(path, linewidth=0.8) 
plt.title("Vasicek Simulation (100 Paths)")
plt.xlabel("Time (in days)")
plt.ylabel("Interest Rate (*100%)")
plt.show()
